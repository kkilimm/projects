# %%
1. Тир 1 - очень маленький сегмент
Что вижу: у тира 1 всего 4 клиента, тогда как у тира 2 - 16, а у тира 3 - 30.

Почему важно: любые выводы по тиру 1 очень чувствительны к поведению каждого отдельного клиента, поэтому сегмент нельзя считать статистически устойчивым.

Что дальше: не принимать по нему решения без дополнительной выборки.

2. Тир 1 бронирует дороже и чаще
Что вижу: клиенты тира 1 имеют самый большой средний чек и при этом совершают больше всего бронирований на клиента.

Почему важно: это отвергает гипотезу о том, что клиенты тира 1 бронируют реже, чем остальные.

Что дальше: разложить результаты по каждому клиенту в отдельности, чтобы понять, не создаёт ли весь объем в тире 1 один-два крупных клиента.

3. Тир 2 - основной тир, который стоит масштабировать.
Что вижу: у тира 2 примерно в 2 раза меньше средней чек и примерно в 2 раза меньше количество бронирований на клиента, чем у тира 1.
Но ровно в 4 раза больше клиентов.

Почему важно: на одного нового клиента тира 1 нужны примерно 4 новых клиента тира 2.
    
Что дальше: попробовать высчитать приблизительную стоимость нового клиента тира 1 и тира 2. 
Если окажется, что привлечь нового клиента тира 1 стоит в 5 или более раз дороже, чем клиента тира 2, то тир 2 действительно является самым выжным для масштабирования. 
В этом случае нужно отдельно изучить удержание, долю отмен и структуру бронирований по субпродуктам у тира 2, чтобы понять, где у него потенциальные точки роста.

4. В 2025 году «новых клиентов» по first_booking_date нет
Что вижу: все клиенты в таблицу clients имеют first_booking_date в 2024 году.

Почему важно: когортный анализ по «новым клиентам» невозможен, потому что такой выборки просто нет.

Что дальше: если нужен retention, нужно считать когорты по первому confirmed бронированию в bookings.
